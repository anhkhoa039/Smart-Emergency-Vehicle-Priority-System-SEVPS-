# %%
import traci
import networkx as nx
import numpy as np
from typing import Dict, List, Optional, Tuple
import sumolib
from pathlib import Path

class EmergencyRouter:
    def __init__(self):
        """Initialize the emergency router with a directed graph"""
        self.network = nx.DiGraph()
        # Load the network file
        self.net = sumolib.net.readNet('additional/osm.net.xml')
        # Network will be built when first needed
        self.nodes = [node.getID() for node in self.net.getNodes()]
    
    def _build_network(self):
        """Build the network graph from SUMO network"""
        # Clear existing network
        self.network.clear()
        # ===============================================
        # Add nodes (junctions)
        for junction in self.net.getNodes():
            self.network.add_node(junction.getID())
        # ===============================================

        # Add edges (roads)
        for edge in self.net.getEdges():
            from_node = edge.getFromNode().getID()
            to_node = edge.getToNode().getID()
            length = edge.getLength()
            self.network.add_edge(from_node, to_node, weight=length, edge_id=edge.getID())

        print ("Loaded graph with ", len(self.network.nodes()), " nodes and ", len(self.network.edges()), " edges")

        # ===============================================

    def optimize_route(self, emergency_vehicle: Dict) -> Optional[List[str]]:
        """
        Optimize route for an emergency vehicle based on current traffic conditions
        
        Args:
            emergency_vehicle: Dictionary containing vehicle information
            
        Returns:
            List of edge IDs representing the optimized route, or None if no route found
        """
        # Build network if not already built
        if len(self.network.edges) == 0:
            self._build_network()
        # Get current position and destination
        current_edge = traci.vehicle.getRoadID(emergency_vehicle['id'])
        if current_edge.startswith(":"):
            print ("==== [Debug] ==== : Vehicle is in junction")
            parts = current_edge.replace(":", "").split("_")[:-1]
            current_node = "_".join(parts)
            return None
        elif current_edge in self.nodes:
            print ("==== [Debug] ==== : Vehicle is in junction")
            current_node = current_edge
            return None
        else:   
            current_node = self._get_current_node(current_edge,type='from')

        print ("==== [Debug] ==== : current_edge: ",current_edge)

        print ("==== [Debug] ==== : current_node: ",current_node)

        route = emergency_vehicle['route']
        destination = route[-1]
        destination_node = self._get_current_node(destination,type='to')
        print ("==== [Debug] ==== : destination_edge: ",destination)
        print ("==== [Debug] ==== : destination_node: ",destination_node)

        if current_node == destination_node:
            print ("==== [Debug] ==== : current_node is the same as destination_node")
            return None
        # Update edge weights based on current traffic conditions
        self._update_edge_weights()
        
        try:
            # Find shortest path using Dijkstra's algorithm
            path = nx.shortest_path(
                self.network,
                source=current_node,
                target=destination_node,
                weight='weight'
            )
            
            # Convert node path to edge path
            edge_path = []
            for i in range(len(path) - 1):
                edge = self.network[path[i]][path[i + 1]]['edge_id']
                edge_path.append(edge)
            print ("==== [Debug] ==== : edge_path: ",path)
            return [current_edge] + edge_path
            
        except nx.NetworkXNoPath:
            print(f"No path found for vehicle {emergency_vehicle['id']}")
            return None
    
    def _update_edge_weights(self):
        """Update edge weights based on current traffic conditions"""

        edge_id_list = [edge.getID() for edge in self.net.getEdges()]

        
        # for edge_id in traci.edge.getIDList():
        for edge_id in edge_id_list:
            # Get current traffic data
            vehicle_count = traci.edge.getLastStepVehicleNumber(edge_id)
            mean_speed = traci.edge.getLastStepMeanSpeed(edge_id)
            
            # Get edge from network
        
            edge = self.net.getEdge(edge_id)
            if edge:
                max_speed = edge.getSpeed()
                
                # Calculate congestion factor
                if mean_speed > 0:
                    congestion_factor = 1 + (vehicle_count * (1 - mean_speed/max_speed))
                else:
                    congestion_factor = float('inf')
                
                # Update edge weight
                base_length = edge.getLength()
                from_node = edge.getFromNode().getID()
                to_node = edge.getToNode().getID()
                
                if self.network.has_edge(from_node, to_node):
                    self.network[from_node][to_node]['weight'] = base_length * congestion_factor
    def _get_current_node(self, edge_id,type='from'):
        edge = self.net.getEdge(edge_id)
        if edge:
            if type == 'from':
                return edge.getToNode().getID()
            elif type == 'to':
                return edge.getToNode().getID()
        else:
            return None
        
    def get_route_metrics(self, route: List[str]) -> Dict[str, float]:
        """
        Calculate metrics for a given route
        
        Args:
            route: List of edge IDs representing the route
            
        Returns:
            Dictionary containing route metrics
        """
        total_length = 0
        total_time = 0
        
        for edge_id in route:
            # Get edge from network
            edge = self.net.getEdge(edge_id)
            if edge:
                # Get edge length
                length = edge.getLength()
                total_length += length
                
                # Estimate time based on current speed
                mean_speed = traci.edge.getLastStepMeanSpeed(edge_id)
                if mean_speed > 0:
                    total_time += length / mean_speed
        
        return {
            'total_length': total_length,
            'estimated_time': total_time,
            'num_edges': len(route)
        }

# %%
def bulid_graph ():
    net = sumolib.net.readNet('additional/osm.net.xml')
    graph = nx.DiGraph()
    # Add nodes (junctions)
    for junction in net.getNodes():
        graph.add_node(junction.getID())

    # Add edges (roads)
    for edge in net.getEdges():
        if edge.allows('passenger'):
            from_node = edge.getFromNode().getID()
            to_node = edge.getToNode().getID()
            length = edge.getLength()
            graph.add_edge(from_node, to_node, weight=length, edge_id=edge.getID())

    return graph, net
        
def is_emergency_vehicle(veh_id):
    """Check if a vehicle is an emergency vehicle"""
    try:
        veh_type = traci.vehicle.getTypeID(veh_id)
        return veh_type in ['ambulance', 'fire_truck', 'police']
    except Exception as e:
        print(f"❌ Vehicle type check error for {veh_id}: {str(e)}")
        return False

def test_emergency_detection():
    """Test emergency vehicle detection"""
    try:
        emergency_vehicles = []
        for veh_id in traci.vehicle.getIDList():
            if is_emergency_vehicle(veh_id):
                emergency_vehicles.append({
                    'id': veh_id,
                    'position': traci.vehicle.getPosition(veh_id),
                    'speed': traci.vehicle.getSpeed(veh_id),
                    'route': traci.vehicle.getRoute(veh_id),
                    'type': traci.vehicle.getTypeID(veh_id)
                })
        
        if emergency_vehicles:
            print(f"✓ Detected {len(emergency_vehicles)} emergency vehicles")
        
        return emergency_vehicles
        
    except Exception as e:
        print(f"❌ Emergency detection error: {str(e)}")
        return []
    

def update_vehicle_route(vehicle_id, new_route):
    """Update vehicle's route with the optimized route"""
    try:
        # Get current route
        current_route = traci.vehicle.getRoute(vehicle_id)
        
        # Only update if the new route is different
        if new_route != current_route:
            print(f"\n🔄 Updating route for vehicle {vehicle_id}")
            print(f"Original route: {current_route}")
            print(f"New optimized route: {new_route}")
            
            # Update the route
            traci.vehicle.setRoute(vehicle_id, new_route)
            print("✓ Route updated successfully")
            
            # Highlight the new route edges
            for edge_id in new_route:
                traci.edge.setColor(edge_id, (0, 255, 0, 255))  # Green color for optimized route
    except Exception as e:
        print(f"❌ Error updating route: {str(e)}")

# %%
def run_simulation():
    """Run a simple SUMO simulation with TraCI"""

    # Initialize SUMO
    print("=== Starting SUMO Simulation ===")
    
    # Get the path to the SUMO configuration file
    sumocfg_path = 'osm.sumocfg'
    
    # Start SUMO with GUI
    sumo_binary = sumolib.checkBinary('sumo-gui')
    traci.start([sumo_binary, '-c', sumocfg_path])
    
    # Simulation loop
    step = 0
    max_steps = 500  # Run for 1 hour of simulation time
    
    print ("\n\n\n===============================================")
    print(f"Simulation will run for {max_steps} steps")
    # ===============================================
    # initialize 
    graph, net = bulid_graph()
    print ("Loaded graph with ", len(graph.nodes()), " nodes and ", len(graph.edges()), " edges")
    router = EmergencyRouter()
    router._build_network()
    # ===============================================


    while step < max_steps and traci.simulation.getMinExpectedNumber() > 0:
        # Perform simulation step
        traci.simulationStep()
        # ===============================================
        # Test emergency vehicle detection
        if step % 10 == 0:
            emergency_vehicles = test_emergency_detection()
 
            for ev in emergency_vehicles:
                ev_id = ev['id']
                ev_type = ev['type'] 
                print(f"  - {ev_type}: {ev_id}")
                original_route = traci.vehicle.getRoute(ev_id)
                print (f"Original Route of {ev_id}: ",original_route)
                optimized_route = router.optimize_route(ev)
                print (f"Optimized Route for {ev_id}: ",optimized_route)
                if optimized_route and optimized_route != original_route:
                    print(f"✓ Route optimized for {ev_id}")
                    traci.vehicle.setRoute(ev_id, optimized_route)
                    print("✓ Route updated successfully")
                else:
                    print ("No optimization")
                
        step += 1
    
    print("\n=== Simulation Complete ===")
    print(f"Total steps: {step}")
        

    traci.close()

if __name__ == "__main__":
    run_simulation()
# Out:
# === Starting SUMO Simulation ===
#  Retrying in 1 seconds
# Warning: Could not set locale to 'C'.
# ===============================================
# Simulation will run for 500 steps
# Loaded graph with  682  nodes and  475  edges
# ✓ Detected 1 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  308558730
# ==== [Debug] ==== : Route real time:  ('308558730', '-518147860#4', '-518147860#3', '-518147860#2', '-518147861', '-238483769#2', '-238483769#1', '-238483769#0', '238483771#0', '238483771#1', '238483771#2', '1326528807#0', '1326528807#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '-518147860#4', '-518147860#3', '-518147860#2', '-518147861', '-238483769#2', '-238483769#1', '-238483769#0', '238483771#0', '238483771#1', '238483771#2', '1326528807#0', '1326528807#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  308558730
# ==== [Debug] ==== : current_node:  cluster_1270070821_1270070862
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['cluster_1270070821_1270070862', '5080634555', '4397729982', '2749352883', '3231613005', '3297116419', 'cluster_1224950879_1270070823_3231613004', 'cluster_12208658492_4384310839', '3826934028', '4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
# ✓ Detected 1 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  308558730
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  308558730
# ==== [Debug] ==== : current_node:  cluster_1270070821_1270070862
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['cluster_1270070821_1270070862', '5080634555', '4397729982', '2749352883', '3231613005', '3297116419', 'cluster_1224950879_1270070823_3231613004', 'cluster_12208658492_4384310839', '3826934028', '4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
# ✓ Detected 2 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  111484735#0
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  111484735#0
# ==== [Debug] ==== : current_node:  5080634555
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['5080634555', '4397729982', '2749352883', '3231613005', '3297116419', 'cluster_1224950879_1270070823_3231613004', 'cluster_12208658492_4384310839', '3826934028', '4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  909564596#0
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894631#0', '916894631#1', '916894631#3', '916894631#4', '916894631#6', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894631#0', '916894631#1', '916894631#3', '916894631#4', '916894631#6', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  909564596#0
# ==== [Debug] ==== : current_node:  3423346397
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : edge_path:  ['3423346397', '3423377594', '8515931777', '1224155262', 'cluster_2465505574_2465505577', '2465505572', '2531692326', '4214247634', '4225165336', '2465505583', '2465505585', '2218996611', '2463164198', '3750163966', '2218996569', '2218996604', '2218996564', '3750187662', '3750188012', '1224155148', '3750156742', '2463164195', 'cluster_2463164192_3750132390', '3750131108', '2463164190', '2463164187', '4214247629', '2463164183']
# Optimized Route for police1:  ['909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8']
# ✓ Route optimized for police1
# ✓ Route updated successfully
# ✓ Detected 2 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  111484735#4
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  111484735#4
# ==== [Debug] ==== : current_node:  3231613005
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['3231613005', '3297116419', 'cluster_1224950879_1270070823_3231613004', 'cluster_12208658492_4384310839', '3826934028', '4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  :cluster_2465505574_2465505577_11
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : Vehicle is in junction
# Optimized Route for police1:  None
# No optimization
# ✓ Detected 2 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  316970951#1
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  316970951#1
# ==== [Debug] ==== : current_node:  cluster_1224950879_1270070823_3231613004
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['cluster_1224950879_1270070823_3231613004', 'cluster_12208658492_4384310839', '3826934028', '4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  421669212
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  421669212
# ==== [Debug] ==== : current_node:  2218996611
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : edge_path:  ['2218996611', '2463164198', '3750163966', '2218996569', '2218996604', '2218996564', '3750187662', '3750188012', '1224155148', '3750156742', '2463164195', 'cluster_2463164192_3750132390', '3750131108', '2463164190', '2463164187', '4214247629', '2463164183']
# Optimized Route for police1:  ['421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8']
# ✓ Route optimized for police1
# ✓ Route updated successfully
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  :cluster_1224950879_1270070823_3231613004_20
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : Vehicle is in junction
# Optimized Route for amb1:  None
# No optimization
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  -494873600
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '231534775#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '231534775#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  -494873600
# ==== [Debug] ==== : current_node:  1224949924
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['1224949924', '3750195555', 'cluster_1224155382_412721867', '4160748794', '1224155045', 'cluster_345178346_345178350', '2839792899', '282283330', '6937731092', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['-494873600', '-383637302#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  :2218996604_2
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : Vehicle is in junction
# Optimized Route for police1:  None
# No optimization
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  150871017#2
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  150871017#2
# ==== [Debug] ==== : current_node:  3826934028
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['3826934028', '4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  -383637302#1
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  -383637302#1
# ==== [Debug] ==== : current_node:  3750195555
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['3750195555', '3869475567', '3750196056', '3750195553', '4866466763', '1224950851', '1224950575', '4416069911', '1224950194', '4866466746', 'cluster_3826934026_3901342335', '1224155406', 'cluster_1224155127_1224155195_1224950200_1224950229_#3more', 'cluster_1224950804_1270071028', 'cluster_1224950879_1270070823_3231613004', 'cluster_12208658492_4384310839', '3826934028', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['-383637302#1', '-371457993#1', '371457957#1', '106484927#1', '106484927#2', '106484927#3', '106484927#4', '106484927#5', '106484927#6', '106484927#7', '106484927#8', '106484927#10', '198582302#7', '106484949#4', '106484949#5', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  211983879#10
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  211983879#10
# ==== [Debug] ==== : current_node:  2218996564
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : edge_path:  ['2218996564', '3750187662', '3750188012', '1224155148', '3750156742', '2463164195', 'cluster_2463164192_3750132390', '3750131108', '2463164190', '2463164187', '4214247629', '2463164183']
# Optimized Route for police1:  ['211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8']
# ✓ Route optimized for police1
# ✓ Route updated successfully
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  150871017#3
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  150871017#3
# ==== [Debug] ==== : current_node:  4392471443
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['4392471443', '4392471442', '4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  371457957#1
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '106484927#1', '106484927#2', '106484927#3', '106484927#4', '106484927#5', '106484927#6', '106484927#7', '106484927#8', '106484927#10', '198582302#7', '106484949#4', '106484949#5', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '106484927#1', '106484927#2', '106484927#3', '106484927#4', '106484927#5', '106484927#6', '106484927#7', '106484927#8', '106484927#10', '198582302#7', '106484949#4', '106484949#5', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  371457957#1
# ==== [Debug] ==== : current_node:  3750196056
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['3750196056', '3869475567', '3750195555', 'cluster_1224155382_412721867', '4160748794', '1224155045', 'cluster_345178346_345178350', '2839792899', '282283330', '6937731092', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  198414900#3
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  198414900#3
# ==== [Debug] ==== : current_node:  3750187662
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : edge_path:  ['3750187662', '3750188012', '1224155148', '3750156742', '2463164195', 'cluster_2463164192_3750132390', '3750131108', '2463164190', '2463164187', '4214247629', '2463164183']
# Optimized Route for police1:  ['198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8']
# ✓ Route optimized for police1
# ✓ Route updated successfully
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  231534780#1
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  231534780#1
# ==== [Debug] ==== : current_node:  4392471440
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['4392471440', '282282891', '2100192558', '3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  :3750195555_6
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : Vehicle is in junction
# Optimized Route for fire1:  None
# No optimization
#   - police: police1
# ==== [Debug] ==== : Edge real time:  -6183287#16
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  -6183287#16
# ==== [Debug] ==== : current_node:  3750156742
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : edge_path:  ['3750156742', '2463164195', 'cluster_2463164192_3750132390', '3750131108', '2463164190', '2463164187', '4214247629', '2463164183']
# Optimized Route for police1:  ['-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8']
# ✓ Route optimized for police1
# ✓ Route updated successfully
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  198414888#0
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  198414888#0
# ==== [Debug] ==== : current_node:  3365328803
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['3365328803', 'cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['198414888#0', '198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  -238348991#3
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  -238348991#3
# ==== [Debug] ==== : current_node:  4160748794
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['4160748794', '1224155045', 'cluster_345178346_345178350', '2839792899', '282283330', '6937731092', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  -6183287#10
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  -6183287#10
# ==== [Debug] ==== : current_node:  2463164187
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : edge_path:  ['2463164187', '4214247629', '2463164183']
# Optimized Route for police1:  ['-6183287#10', '-6183287#9', '-6183287#8']
# ✓ Route optimized for police1
# ✓ Route updated successfully
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  198414888#1
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  198414888#1
# ==== [Debug] ==== : current_node:  cluster_345178346_345178350
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['cluster_345178346_345178350', '2218996568', '282282903']
# Optimized Route for amb1:  ['198414888#1', '238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  -238348991#1
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  -238348991#1
# ==== [Debug] ==== : current_node:  cluster_345178346_345178350
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['cluster_345178346_345178350', '2839792899', '282283330', '6937731092', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
#   - police: police1
# ==== [Debug] ==== : Edge real time:  -6183287#8
# ==== [Debug] ==== : Route real time:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# Original Route of police1:  ('909564596#0', '909564596#1', '243199092#1', '916894634', '916894630#0', '916894632', '469939708', '238751389#0', '238751389#1', '238751389#2', '421669211', '421669212', '211983879#6', '211983879#7', '211983879#8', '211983879#9', '211983879#10', '198414900#3', '198414900#4', '198414900#5', '-6183287#16', '-6183287#15', '-6183287#14', '-6183287#12', '-6183287#11', '-6183287#10', '-6183287#9', '-6183287#8')
# ==== [Debug] ==== : current_edge:  -6183287#8
# ==== [Debug] ==== : current_node:  2463164183
# ==== [Debug] ==== : destination_edge:  -6183287#8
# ==== [Debug] ==== : destination_node:  2463164183
# ==== [Debug] ==== : current_node is the same as destination_node
# Optimized Route for police1:  None
# No optimization
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb1
# ==== [Debug] ==== : Edge real time:  238742346#0
# ==== [Debug] ==== : Route real time:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# Original Route of amb1:  ('308558730', '111484735#0', '111484735#1', '111484735#2', '111484735#4', '316970951#0', '316970951#1', '150871017#0', '150871017#2', '150871017#3', '231534780#0', '231534780#1', '441500155#0', '441500155#1', '198414888#0', '198414888#1', '238742346#0', '238742346#2')
# ==== [Debug] ==== : current_edge:  238742346#0
# ==== [Debug] ==== : current_node:  2218996568
# ==== [Debug] ==== : destination_edge:  238742346#2
# ==== [Debug] ==== : destination_node:  282282903
# ==== [Debug] ==== : edge_path:  ['2218996568', '282282903']
# Optimized Route for amb1:  ['238742346#0', '238742346#2']
# ✓ Route optimized for amb1
# ✓ Route updated successfully
#   - ambulance: amb2
# ==== [Debug] ==== : Edge real time:  494873607
# ==== [Debug] ==== : Route real time:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '308447230#5', '106373390#0', '106373390#2', '106373390#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# Original Route of amb2:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '308447230#5', '106373390#0', '106373390#2', '106373390#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# ==== [Debug] ==== : current_edge:  494873607
# ==== [Debug] ==== : current_node:  1224155393
# ==== [Debug] ==== : destination_edge:  229193804#3
# ==== [Debug] ==== : destination_node:  1224155084
# ==== [Debug] ==== : edge_path:  ['1224155393', '3750188712', '2137955806', '3750203701', '1224155060', '3750206450', '2619346940', 'cluster_1224155297_2443300978', 'cluster_1224155017_1224155028_3987560858', '3750193209', '12112549816', 'cluster_1224155118_1224155193', '2958518293', '2218996564', '3750187662', '3750188012', '1224155148', '1224155414', '3645921574', '1224155084']
# Optimized Route for amb2:  ['494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '308447230#5', '106373390#0', '106373390#2', '106373390#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3']
# ✓ Route optimized for amb2
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  -238348991#1
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  -238348991#1
# ==== [Debug] ==== : current_node:  cluster_345178346_345178350
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['cluster_345178346_345178350', '2839792899', '282283330', '6937731092', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
# ✓ Detected 2 emergency vehicles
#   - ambulance: amb2
# ==== [Debug] ==== : Edge real time:  106373392#3
# ==== [Debug] ==== : Route real time:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '308447230#5', '106373390#0', '106373390#2', '106373390#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# Original Route of amb2:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '308447230#5', '106373390#0', '106373390#2', '106373390#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# ==== [Debug] ==== : current_edge:  106373392#3
# ==== [Debug] ==== : current_node:  1224155060
# ==== [Debug] ==== : destination_edge:  229193804#3
# ==== [Debug] ==== : destination_node:  1224155084
# ==== [Debug] ==== : edge_path:  ['1224155060', '3750206450', '2619346940', 'cluster_1224155297_2443300978', '3750190012', '3750193208', '3750191523', '3750191504', 'cluster_1224155118_1224155193', '2958518293', '2218996564', '3750187662', '3750188012', '1224155148', '1224155414', '3645921574', '1224155084']
# Optimized Route for amb2:  ['106373392#3', '256262135#0', '256262135#1', '256261974#1', '106373389#0', '106373389#1', '106373389#2', '106373389#3', '106373389#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3']
# ✓ Route optimized for amb2
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  :cluster_345178346_345178350_0
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : Vehicle is in junction
# Optimized Route for fire1:  None
# No optimization
# ✓ Detected 2 emergency vehicles
#   - ambulance: amb2
# ==== [Debug] ==== : Edge real time:  :cluster_1224155297_2443300978_1
# ==== [Debug] ==== : Route real time:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '106373389#0', '106373389#1', '106373389#2', '106373389#3', '106373389#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# Original Route of amb2:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '106373389#0', '106373389#1', '106373389#2', '106373389#3', '106373389#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# ==== [Debug] ==== : Vehicle is in junction
# Optimized Route for amb2:  None
# No optimization
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  198582305#0
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  198582305#0
# ==== [Debug] ==== : current_node:  2839792899
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['2839792899', '282283330', '6937731092', '4392471443', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
# ✓ Detected 3 emergency vehicles
#   - ambulance: amb2
# ==== [Debug] ==== : Edge real time:  106373389#3
# ==== [Debug] ==== : Route real time:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '106373389#0', '106373389#1', '106373389#2', '106373389#3', '106373389#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# Original Route of amb2:  ('494873607', '106373392#0', '106373392#1', '106373392#2', '106373392#3', '256262135#0', '256262135#1', '256261974#1', '106373389#0', '106373389#1', '106373389#2', '106373389#3', '106373389#4', '198414900#0', '198414900#2', '198414900#3', '198414900#4', '198414900#5', '229193804#0', '229193804#1', '229193804#3')
# ==== [Debug] ==== : current_edge:  106373389#3
# ==== [Debug] ==== : current_node:  3750191504
# ==== [Debug] ==== : destination_edge:  229193804#3
# ==== [Debug] ==== : destination_node:  1224155084
# ==== [Debug] ==== : edge_path:  ['3750191504', 'cluster_1224155118_1224155193', '2958518293', '2218996564', '2218996583', '2218996622', '3750188139', '2686650919', '3750187661', '2686686424', '3750187755', '1224155048', '1224155386', '1224155148', '1224155414', '3645921574', '1224155084']
# Optimized Route for amb2:  ['106373389#3', '106373389#4', '198414900#0', '198414900#2', '211983879#11', '211983879#12', '329613063#3', '329613063#4', '329613063#5', '329613063#6', '329613063#7', '329613063#8', '329613063#9', '-229193799#0', '229193804#0', '229193804#1', '229193804#3']
# ✓ Route optimized for amb2
# ✓ Route updated successfully
#   - fire_truck: fire1
# ==== [Debug] ==== : Edge real time:  441500157#1
# ==== [Debug] ==== : Route real time:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# Original Route of fire1:  ('-494873600', '-383637302#1', '-371457993#1', '371457957#1', '-371457957#1', '371457993#1', '-383637302#0', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '441500157#0', '441500157#1', '231534780#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522')
# ==== [Debug] ==== : current_edge:  441500157#1
# ==== [Debug] ==== : current_node:  4392471443
# ==== [Debug] ==== : destination_edge:  150872522
# ==== [Debug] ==== : destination_node:  1012067769
# ==== [Debug] ==== : edge_path:  ['4392471443', '3826934028', 'cluster_12208658492_4384310839', 'cluster_1224950879_1270070823_3231613004', 'cluster_1224950804_1270071028', 'cluster_1224155127_1224155195_1224950200_1224950229_#3more', '1224155062', '3826934033', '3826934030', '3479095244', '3826934024', '4384310832', '3145529329', '3901176493', 'cluster_1224155382_412721867', '4160748794', '1224155045', 'cluster_345178346_345178350', '2839792899', '282283330', '4392471442', '4866466790', '3297116417', '282283323', '282283310', '1012067769']
# Optimized Route for fire1:  ['441500157#1', '-150871017#3', '-150871017#2', '-150871017#0', '111484721#0', '111484721#1', '246666471#0', '246666471#1', '246666471#3', '246666471#4', '246666471#5', '246666471#6', '246666471#7', '246666471#8', '246666471#9', '-238348991#3', '-238348991#2', '-238348991#1', '198582305#0', '198582305#2', '231534775#0', '231534775#2', '231534775#5', '231534775#6', '25878619', '150872522']
# ✓ Route optimized for fire1
# ✓ Route updated successfully
#   - police: police2
# ==== [Debug] ==== : Edge real time:  -238483769#2
# ==== [Debug] ==== : Route real time:  ('-238483769#2', '-238483769#1', '-238483769#0', '238483771#0', '238483771#1', '238483771#2', '1326528807#0', '1326528807#1', '238348991#0', '238348991#2', '238348991#3', '308447230#0', '-236288233#2', '-236288233#1', '-236288233#0')
# Original Route of police2:  ('-238483769#2', '-238483769#1', '-238483769#0', '238483771#0', '238483771#1', '238483771#2', '1326528807#0', '1326528807#1', '238348991#0', '238348991#2', '238348991#3', '308447230#0', '-236288233#2', '-236288233#1', '-236288233#0')
# ==== [Debug] ==== : current_edge:  -238483769#2
# ==== [Debug] ==== : current_node:  5055061929
# ==== [Debug] ==== : destination_edge:  -236288233#0
# ==== [Debug] ==== : destination_node:  2443300972
# ==== [Debug] ==== : edge_path:  ['5055061929', '5068315294', '1224155164', '12273587693', '12273587694', 'cluster_2531692323_2531692324', '2839792889', 'cluster_345178346_345178350', '1224155045', '4160748794', 'cluster_1224155382_412721867', 'cluster_2137955738_2443300976', '2443300974', '7742908534', '2443300972']
# Optimized Route for police2:  ['-238483769#2', '-238483769#1', '-238483769#0', '238483771#0', '238483771#1', '238483771#2', '1326528807#0', '1326528807#1', '238348991#0', '238348991#2', '238348991#3', '308447230#0', '-236288233#2', '-236288233#1', '-236288233#0']
# ✓ Route optimized for police2
# ✓ Route updated successfully
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# Cell In[5], line 100
#      97     traci.close()
#      99 if __name__ == "__main__":
# --> 100     run_simulation()
#
# Cell In[5], line 31, in run_simulation()
#      26 # ===============================================
#      29 while step < max_steps and traci.simulation.getMinExpectedNumber() > 0:
#      30     # Perform simulation step
# ---> 31     traci.simulationStep()
#      32     # ===============================================
#      33     # Test emergency vehicle detection
#      34     if step % 10 == 0:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/sumo_env/lib/python3.9/site-packages/traci/main.py:198, in simulationStep(step)
#     192 def simulationStep(step=0):
#     193     """simulationStep(float) -> None
#     194     Make a simulation step and simulate up to the given second in sim time.
#     195     If the given value is 0 or absent, exactly one step is performed.
#     196     Values smaller than or equal to the current sim time result in no action.
#     197     """
# --> 198     connection.check().simulationStep(step)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/sumo_env/lib/python3.9/site-packages/traci/connection.py:370, in Connection.simulationStep(self, step)
#     368 if type(step) is int and step >= 1000:
#     369     warnings.warn("API change now handles step as floating point seconds", stacklevel=2)
# --> 370 result = self._sendCmd(tc.CMD_SIMSTEP, None, None, "D", step)
#     371 for subscriptionResults in self._subscriptionMapping.values():
#     372     subscriptionResults.reset()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/sumo_env/lib/python3.9/site-packages/traci/connection.py:232, in Connection._sendCmd(self, cmdID, varID, objID, format, *values)
#     230     self._string += struct.pack("!i", len(objID)) + objID
#     231 self._string += packed
# --> 232 return self._sendExact()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/sumo_env/lib/python3.9/site-packages/traci/connection.py:137, in Connection._sendExact(self)
#     135     self._socket.close()
#     136     self._socket = None
# --> 137     raise FatalTraCIError("Connection closed by SUMO.")
#     138 for command in self._queue:
#     139     prefix = result.read("!BBB")
#
# FatalTraCIError: Connection closed by SUMO.
